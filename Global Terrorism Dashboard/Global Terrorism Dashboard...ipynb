# %% [markdown]
# # ** Insights**
# 1.target v/s success :
#  observed that around 0.16M targets were successful.
#
# 2.success v/s attack type:
#  we have observed that over 78k attacks were successful with the help of bombing/explosion.
#
# 3.sucess rate v/s region:
#  Middle east and North Africa has the highest success rate(around 44k),followed by south Asia.
#
# 4.weapon type v/s attack type:
#   most of the attacks were successfully done with weapon type Unarmed assault.
#
# 5.weapon type:
#   most used weapon type is Bombing/explosion.
#
# 6.sum of success rate over year is 323627910.

# %% [markdown]
# # Displaying Terrorism Dashboard

# %%
from IPython.display import Image
Image(filename="IMG_20231212_214840.jpg")
